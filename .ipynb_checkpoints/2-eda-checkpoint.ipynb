# %% [markdown]
# # EDA
# To prepare for modeling, we need a deeper understanding of the features we are working with, as well as those we are trying to predict. Some potential steps to take, along with further data cleaning along the way:
#
# - distribution of ratings
# - date FA, person FA (filtering + value counts, will take feature engineering and abstraction), areas, route types
# - correlation between ratings and year established (only numeric variable)
# - word counts per, characters per, etc.
# - correlation between ratings and length of description etc?
# - preprocessing - tokenize, lemmatize, then round 2 EDA bigrams, ngrams, etc.
# - word2vec could be used to look at similarities between route descriptions
# - unsupervised learning to group routes and cluster

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

plt.rc("font", size=16)
plt.rc("xtick", labelsize=12)
plt.rc("ytick", labelsize=12)
plt.rc("axes", labelsize=14)
plt.rc("legend", fontsize=12)

# %% [markdown]
# ### Read in Data and Summary Statistics

# %%
routes = pd.read_csv('./data/routes.csv')

# %%
routes.head()
# Out:
#             route_name safety  \
# 0           Gravel Pit    NaN
# 1       Random Impulse    NaN
# 2         Orange Crush    NaN
# 3  Wimovi Wonder Winos    NaN
# 4       Stand and Fall    NaN
#
#                                                 fa  \
# 0           Jason Milford/ Matt Schutz Spring 2020
# 1                                     "Unknown" or
# 2  Wade Griffith, Sterling Killion, Scott Williams
# 3                                  Kroll and McHam
# 4                                    Bryan Carroll
#
#                                          description  \
# 0  Goes up slab on bolts to steep corner on gear....
# 1  Some fun moves broken up by a few scree filled...
# 2  Pretty cool orange arete that sports some inte...
# 3  Climb the most open looking slab on the more e...
# 4  Best route on the wall. Crux is moving from to...
#
#                                             location  \
# 0                                                NaN
# 1    25 feet to the right of Deep Springs Education.
# 2  The route is located on the far southern shoul...
# 3     Upper right of the wall, more facing the road.
# 4  Start at obious fist-sized crack in center of ...
#
#                                           protection grade.YDS  type.trad  \
# 0  Chains on top, can lower off easy. Pro to 3" a...   5.12b/c          1
# 1  A small assortment of cams and maybe a nut or two       5.7          1
# 2                                             7 QD's   5.11b/c          0
# 3                                              Bolts     5.10-          0
# 4  Use tree with 14 inch diameter at top to set u...     5.10-          0
#
#    metadata.parent_lnglat             metadata.parent_sector  ...  \
# 0   [-118.20202, 35.4963]                      Beerhorn Crag  ...
# 1   [-118.13831, 37.3129]  Westgard Pass East Side (Hwy 168)  ...
# 2    [-119.3094, 37.1667]    Yeti Dome (aka Musick Mountain)  ...
# 3  [-119.31008, 37.14469]                      Wimovi Pluton  ...
# 4    [-119.1022, 37.2914]                    Wilderness Wall  ...
#
#    type.alpine  type.snow type.mixed  type.ice  grade_numeric  plus  minus  \
# 0            0          0          0         0           12.5     0      0
# 1            0          0          0         0            7.0     0      0
# 2            0          0          0         0           11.5     0      0
# 3            0          0          0         0           10.0     0      1
# 4            1          0          0         0           10.0     0      1
#
#    plus_minus  grade_numeric_plus_minus  year_established
# 0           0                     12.50            2020.0
# 1           0                      7.00               NaN
# 2           0                     11.50               NaN
# 3          -1                     10.25               NaN
# 4          -1                     10.25               NaN
#
# [5 rows x 25 columns]

# %%
routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127513 entries, 0 to 127512
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   route_name                127510 non-null  object
#  1   safety                    13207 non-null   object
#  2   fa                        126340 non-null  object
#  3   description               126529 non-null  object
#  4   location                  99723 non-null   object
#  5   protection                126380 non-null  object
#  6   grade.YDS                 127513 non-null  object
#  7   type.trad                 127513 non-null  int64
#  8   metadata.parent_lnglat    127513 non-null  object
#  9   metadata.parent_sector    127513 non-null  object
#  10  metadata.mp_route_id      127507 non-null  float64
#  11  metadata.mp_sector_id     127513 non-null  int64
#  12  metadata.mp_path          127513 non-null  object
#  13  type.sport                127513 non-null  int64
#  14  type.tr                   127513 non-null  int64
#  15  type.alpine               127513 non-null  int64
#  16  type.snow                 127513 non-null  int64
#  17  type.mixed                127513 non-null  int64
#  18  type.ice                  127513 non-null  int64
#  19  grade_numeric             127513 non-null  float64
#  20  plus                      127513 non-null  int64
#  21  minus                     127513 non-null  int64
#  22  plus_minus                127513 non-null  int64
#  23  grade_numeric_plus_minus  127513 non-null  float64
#  24  year_established          44041 non-null   float64
# dtypes: float64(4), int64(11), object(10)
# memory usage: 24.3+ MB

# %% [markdown]
# I am a bit concerned by the number of null values in the `location` column. This is one of our text features, and losing another almost 30,000 rows from this dataset doesn't seem like a great option. The same goes for year_established, which I thought would be an interesting column to have outside of our text features. I will keep it for EDA, but it cannot be used for modeling without some serious imputation.

# %%
routes.describe().T
# Out:
#                              count          mean           std          min  \
# type.trad                 127513.0  4.672622e-01  4.989290e-01          0.0
# metadata.mp_route_id      127507.0  1.106857e+08  4.987261e+06  105714703.0
# metadata.mp_sector_id     127513.0  1.089597e+08  4.383089e+06  105714297.0
# type.sport                127513.0  4.934634e-01  4.999592e-01          0.0
# type.tr                   127513.0  1.474124e-01  3.545180e-01          0.0
# type.alpine               127513.0  3.626297e-02  1.869445e-01          0.0
# type.snow                 127513.0  1.270459e-03  3.562099e-02          0.0
# type.mixed                127513.0  8.783418e-04  2.962393e-02          0.0
# type.ice                  127513.0  8.940265e-04  2.988702e-02          0.0
# grade_numeric             127513.0  9.687980e+00  2.220043e+00          0.0
# plus                      127513.0  1.023033e-01  3.030479e-01          0.0
# minus                     127513.0  5.046544e-02  2.189042e-01          0.0
# plus_minus                127513.0  5.183785e-02  3.874052e-01         -1.0
# grade_numeric_plus_minus  127513.0  9.777324e+00  2.217949e+00          0.0
# year_established           44041.0  1.997901e+03  4.250913e+01          3.0
#
#                                    25%           50%           75%  \
# type.trad                 0.000000e+00  0.000000e+00  1.000000e+00
# metadata.mp_route_id      1.064022e+08  1.083696e+08  1.141087e+08
# metadata.mp_sector_id     1.058761e+08  1.067506e+08  1.109213e+08
# type.sport                0.000000e+00  0.000000e+00  1.000000e+00
# type.tr                   0.000000e+00  0.000000e+00  0.000000e+00
# type.alpine               0.000000e+00  0.000000e+00  0.000000e+00
# type.snow                 0.000000e+00  0.000000e+00  0.000000e+00
# type.mixed                0.000000e+00  0.000000e+00  0.000000e+00
# type.ice                  0.000000e+00  0.000000e+00  0.000000e+00
# grade_numeric             8.000000e+00  1.020000e+01  1.120000e+01
# plus                      0.000000e+00  0.000000e+00  0.000000e+00
# minus                     0.000000e+00  0.000000e+00  0.000000e+00
# plus_minus                0.000000e+00  0.000000e+00  0.000000e+00
# grade_numeric_plus_minus  8.250000e+00  1.025000e+01  1.125000e+01
# year_established          1.988000e+03  2.000000e+03  2.013000e+03
#
#                                   max
# type.trad                         1.0
# metadata.mp_route_id      121970893.0
# metadata.mp_sector_id     121959816.0
# type.sport                        1.0
# type.tr                           1.0
# type.alpine                       1.0
# type.snow                         1.0
# type.mixed                        1.0
# type.ice                          1.0
# grade_numeric                    15.8
# plus                              1.0
# minus                             1.0
# plus_minus                        1.0
# grade_numeric_plus_minus         15.8
# year_established               2996.0

# %% [markdown]
# Everything looks like what we would expect, with the exception of some possible 0 outliers in grade numeric (we'll check distributions) and some hinky values in our year_established engineered column, which will need a more thorough investigation.

# %%
routes[routes['year_established'] < 1850]['fa']
# Out:
# 6111      This guy and Gabriel L, or someone 1,500 years...
# 13006     Sean Jones, Jake Jones [or Robbie Borchard 2/1...
# 21611                        Jeff Foote, Steve Roper 11/192
# 27997                               John Thomas, August 201
# 50879              Mike Varlotta & Dave Gibson, October 200
# 53696     Swartling & Mayer p.164, route not described b...
# 53790                near Swartling & Mayer p.164, route 17
# 53792                     Swartling & Mayer p.164, route 23
# 53793                     Swartling & Mayer p.164, route 22
# 53794                     Swartling & Mayer p.164, route 13
# 53796                      Swartling & Mayer p.163, route 6
# 53797                     Swartling & Mayer p.164, route 18
# 53800                     Swartling & Mayer p.164, route 21
# 57733               Bill Gilson and Al Haock 1657 Ground Up
# 61691     TR: Steve Wunsch, 104  Lead: The Russes Clune ...
# 61909                                   Phil Jacobus (1060)
# 67343                                       1800s quarrymen
# 67344                                       1800s quarrymen
# 67345                                       1800s quarrymen
# 69294                       Charles Johnson, 1 August, 1834
# 69295                   Charles Johnson, 16 September, 1834
# 85165                       Leo Paik, Joe Keyser, 11/8/003?
# 86697                 Randy Farris and Jim Bourgeois, 12995
# 100960              James Garret, Kathy Harmston. 5/14/200.
# 104473             Drew Chojnowski, Marta Reece, 11/20/1017
# 106859    Danny Rider,  Scott Fielder,  Dennis Zuniga  1...
# 115273       Anasazi Children - betwixt circa 100-1600 A.D.
# 115853    The Jesuits AKA Sam Foreman & the Swamp Donkey...
# 118065                           Old Tradevious, circa 1402
# 121343    Kemper Brightman, Luke Bertelsen, Jillian Were...
# 126612    Trevor Bowman, Pete Thompson, Neil Kauffman  1...
# 126647    Trevor Bowman, Pete Thompson, Neil Kauffman  1...
# 126648    Trevor Bowman, Pete Thompson, Neil Kauffman  1...
# 127222                       Unknown Packrat, circa 200 BCE
# Name: fa, dtype: object

# %%
routes.loc[126648]
# Out:
# route_name                                                         Cap it Off
# safety                                                                    NaN
# fa                          Trevor Bowman, Pete Thompson, Neil Kauffman  1...
# description                 The prominent right-leaning, left-facing dihed...
# location                    On the west face of the upper block, some scra...
# protection                                        Gear to #2 BD, gear anchor.
# grade.YDS                                                                 5.8
# type.trad                                                                   1
# metadata.parent_lnglat                                   [-112.4091, 45.9202]
# metadata.parent_sector                                               Cap Rock
# metadata.mp_route_id                                              109347021.0
# metadata.mp_sector_id                                               109346910
# metadata.mp_path                     Southwest Region|Homestake Pass|Cap Rock
# type.sport                                                                  0
# type.tr                                                                     0
# type.alpine                                                                 0
# type.snow                                                                   0
# type.mixed                                                                  0
# type.ice                                                                    0
# grade_numeric                                                             8.0
# plus                                                                        0
# minus                                                                       0
# plus_minus                                                                  0
# grade_numeric_plus_minus                                                  8.0
# year_established                                                       1026.0
# Name: 126648, dtype: object

# %%
#found on MP
routes.loc[13006, 'year_established'] = 2004

#http://indy-adventures.net/climbing/climb-maryland/TheNarrows.html
routes.loc[50879, 'year_established'] = 2002

#https://pizbube.ch/wp-content/uploads/attachments/a_001/06B40F8DE9063EDAD8A99582C63591B3.pdf
routes.loc[57733, 'year_established'] = 1957

#found in fa description
routes.loc[61691, 'year_established'] = 1983

#https://americanalpineclub.org/news/2022/2/10/gunks-campground-amp-climbing-history
routes.loc[61909, 'year_established'] = 1961

#just mistyped
routes.loc[85165, 'year_established'] = 2003
routes.loc[86697, 'year_established'] = 1995
routes.loc[104473, 'year_established'] = 2017
routes.loc[106859, 'year_established'] = 2009
routes.loc[121343, 'year_established'] = 2018

# %%
#take care of the rest: just need to be nan. 1830-something was the lowest legitimate looking date
years_below_1830 = routes[routes['year_established'] < 1830].index
routes.loc[years_below_1830, 'year_established'] = np.nan

# %%
routes[routes['year_established'] > 2022]
# Out:
#                                 route_name safety  \
# 753                     Art Baker Memorial     PG
# 1518                             Fish Taco    NaN
# 6105                        Clown Syndrome     PG
# 7819                                 Etude    NaN
# 9733                            The Flakes    NaN
# ...                                    ...    ...
# 110436                         North Ridge    NaN
# 110465  Symmetry Crag 4 - Trinity Buttress    NaN
# 110471     Baxter's Pinnacle - South Ridge    NaN
# 114403                            Witblitz      R
# 114445  The Good, the Bad & the Ugly (GBU)     PG
#
#                                                        fa  \
# 753     John Ketcher, Richard Goodsen, Gary Goodsen, 3/70
# 1518    John Mendenhall's half-cyborg son XXXPLRRPRPT ...
# 6105    Chris C. and Taco, or perhaps it was 47 clowns...
# 7819    Larry Reynolds & R. Wendell, 9/69,  FFA: John ...
# 9733    FA: Robbins, Wilson 7/53.  FFA: Long, Sorenson...
# ...                                                   ...
# 110436       Robert Underhill & Fritiof Fryxell (7/17/31)
# 110465            8/1/70  Yvon Chouinard and T.M. Herbert
# 110471  Complete South Ridge Barry Corbet & Robert Fre...
# 114403  FA (A.4) Rusty Baillie, Bill Claggett 2/71, Co...
# 114445  FA Scott Baxter, Karl Karlstrom @ 5.10 A3 1/71...
#
#                                               description  \
# 753     Pitch 1 (160', 5.7): surmount the roof and hea...
# 1518    This route is pretty rad. The rock quality is ...
# 6105    First pitch goes up an easy dihedral to behind...
# 7819    This is a fun, clean crack route that requires...
# 9733    This is one of my favorite Tahquitz routes, al...
# ...                                                   ...
# 110436  From the Lower Saddle, head southwest up and o...
# 110465  For the folks who have climbed many of the cla...
# 110471  Good rock with a sunny southern exposure with ...
# 114403  Witblitz climbs the corner system between The ...
# 114445  An impressive line that is engaging from start...
#
#                                                  location  \
# 753     Turn right at the bottom of the descent trail ...
# 1518    Follow the directions for this crag, taking th...
# 6105    Route runs up noticeable easy dihedral on righ...
# 7819                                                  NaN
# 9733                         Just right of Super Pooper .
# ...                                                   ...
# 110436                                                NaN
# 110465  To find this little adventure, walk past the t...
# 110471  Baxter's is a little difficult to find. I was ...
# 114403  Primarily a right facing system right of Green...
# 114445  Right of the great roof is a large rounded are...
#
#                                                protection grade.YDS  \
# 753     Set of nuts, cams from 0.5 to 2.5 inch, maybe ...       5.9
# 1518    A single rack with some tiny cams is good. Eas...       5.7
# 6105    -Offset nuts (small is best) -Single rack of c...       5.7
# 7819    small to medium pieces plus quickdraws for the...     5.11a
# 9733                                      very thin to 2"   5.11b/c
# ...                                                   ...       ...
# 110436  A few nuts and a couple of tricams. Mark used ...       5.5
# 110465  Standard Teton Rack.  Double set of cams up to...       5.9
# 110471  Standard rack. As noted there are a few fixed ...       5.9
# 114403  Standard GM rack. Brass may or may not be help...     5.10-
# 114445  Doubles from purple c3 to #2 and a full set of...     5.12b
#
#         type.trad  metadata.parent_lnglat  metadata.parent_sector  ...  \
# 753             1    [-119.38392, 37.029]           Memorial Wall  ...
# 1518            1  [-117.92855, 34.31492]              Swagrocrag  ...
# 6105            1  [-117.84635, 34.32886]       Crystal Lake Wall  ...
# 7819            1  [-116.69558, 33.77158]  (u) Northeast Buttress  ...
# 9733            1   [-116.6846, 33.76015]      Upper Bulge Routes  ...
# ...           ...                     ...                     ...  ...
# 110436          1  [-110.81132, 43.72992]            Middle Teton  ...
# 110465          1     [-110.746, 43.7628]          Cascade Canyon  ...
# 110471          1     [-110.746, 43.7628]          Cascade Canyon  ...
# 114403          1  [-112.56665, 34.62908]          Middle Section  ...
# 114445          1  [-112.56665, 34.62908]          Middle Section  ...
#
#         type.alpine  type.snow type.mixed  type.ice  grade_numeric  plus  \
# 753               0          0          0         0            9.0     0
# 1518              1          0          0         0            7.0     0
# 6105              0          0          0         0            7.0     0
# 7819              0          0          0         0           11.2     0
# 9733              0          0          0         0           11.5     0
# ...             ...        ...        ...       ...            ...   ...
# 110436            1          0          0         0            5.0     0
# 110465            1          0          0         0            9.0     0
# 110471            1          0          0         0            9.0     0
# 114403            0          0          0         0           10.0     0
# 114445            0          0          0         0           12.4     0
#
#         minus  plus_minus  grade_numeric_plus_minus  year_established
# 753         0           0                      9.00            2070.0
# 1518        0           0                      7.00            2066.0
# 6105        0           0                      7.00            2047.0
# 7819        0           0                     11.20            2069.0
# 9733        0           0                     11.50            2053.0
# ...       ...         ...                       ...               ...
# 110436      0           0                      5.00            2031.0
# 110465      0           0                      9.00            2070.0
# 110471      0           0                      9.00            2058.0
# 114403      1          -1                     10.25            2071.0
# 114445      0           0                     12.40            2071.0
#
# [74 rows x 25 columns]

# %% [markdown]
# It appears that the date parser parsed many MM/DD/YY dates as being in the 2000s rather than the 1900s or below. This can be solved by simply subtracting 100 years from the date to bring it to the right century.

# %%
years_above_22 = routes[routes['year_established'] > 2022].index
routes.loc[years_above_22, 'year_established'] = routes.loc[years_above_22, 'year_established'] - 100

# %%
routes[routes['year_established'] > 2022]
# Out:
#                            route_name safety  \
# 36091                    Double Stuff    NaN
# 41707  Scarce Women and Nervous Sheep    NaN
#
#                                        fa  \
# 36091  Josh Thurston, Jordan Garvey  2996
# 41707   Tim Bova and Mike Gray, 11/282020
#
#                                              description  \
# 36091         The first pitch has some long, hard moves.
# 41707  Start in the corner, climb up to the ledge, up...
#
#                              location                         protection  \
# 36091  On the left side of Great Arch                  bolts and anchors
# 41707                             NaN  .5 to 3, a #4 makes it less scary
#
#       grade.YDS  type.trad metadata.parent_lnglat metadata.parent_sector  ...  \
# 36091     5.12a          0  [-83.63843, 37.73468]        Great Arch, The  ...
# 41707      5.7+          1  [-79.26769, 38.87567]             Ninja Wall  ...
#
#        type.alpine  type.snow type.mixed  type.ice  grade_numeric  plus  \
# 36091            0          0          0         0           12.2     0
# 41707            0          0          0         0            7.0     1
#
#        minus  plus_minus  grade_numeric_plus_minus  year_established
# 36091      0           0                     12.20            2896.0
# 41707      0           1                      7.75            2720.0
#
# [2 rows x 25 columns]

# %%
#final outliers
routes.loc[36091, 'year_established'] = 1996
routes.loc[41707, 'year_established'] = 2020

# %% [markdown]
# ### Distribution of Grades
# I am curious to see if any type of climb has a significantly distribution of grades than the overall distribution. Overall distribution first.

# %%
grade_labels = [5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, '5.10', 5.11, 5.12, 5.13, 5.14, 5.15]

# %%
plt.figure(figsize=(10, 5))
plt.hist(routes['grade_numeric'], bins=range(0, 16))
plt.xticks(ticks=range(0,16), labels=grade_labels)
plt.title("Total Distribution of Grades")
plt.xlabel("Grade (YDS)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Here we can see that the mass of available grades is around 5.10, with a long left tail into the easier grades. Given the ordinal nature of this problem, grades below 5.6 and above 5.12 may need to be dropped due to lack of training data.

# %%
routes['grade_numeric'].value_counts().sort_index()
# Out:
# 0.00       170
# 1.00       118
# 2.00       400
# 3.00       736
# 4.00      1730
# 5.00      2555
# 6.00      5458
# 7.00      9994
# 8.00     13769
# 9.00     16618
# 10.00     8431
# 10.20     7730
# 10.25     1125
# 10.40     5687
# 10.50     1125
# 10.60     4948
# 10.75      713
# 10.80     3950
# 11.00     5923
# 11.20     5543
# 11.25      737
# 11.40     4168
# 11.50      864
# 11.60     3547
# 11.75      535
# 11.80     2888
# 12.00     2410
# 12.20     4343
# 12.25      584
# 12.40     2683
# 12.50      477
# 12.60     1885
# 12.75      260
# 12.80     1235
# 13.00      581
# 13.20     1379
# 13.25      135
# 13.40      772
# 13.50      113
# 13.60      412
# 13.75       53
# 13.80      270
# 14.00       64
# 14.20      223
# 14.25       21
# 14.40       77
# 14.50        9
# 14.60       35
# 14.75        3
# 14.80       19
# 15.00        3
# 15.20        2
# 15.75        1
# 15.80        2
# Name: grade_numeric, dtype: int64

# %%
routes['grade_numeric_plus_minus'].value_counts().sort_index()
# Out:
# 0.00       170
# 1.00       118
# 2.00       400
# 3.00       736
# 4.00      1730
# 5.00      2555
# 6.00      5458
# 7.00      8494
# 7.75      1500
# 8.00     10434
# 8.25       772
# 8.75      2563
# 9.00     11425
# 9.25      1228
# 9.75      3965
# 10.00     4033
# 10.20     7730
# 10.25     2857
# 10.40     5687
# 10.50     1125
# 10.60     4948
# 10.75     3379
# 10.80     3950
# 11.00     2660
# 11.20     5543
# 11.25     2283
# 11.40     4168
# 11.50      864
# 11.60     3547
# 11.75     2252
# 11.80     2888
# 12.00     1020
# 12.20     4343
# 12.25     1456
# 12.40     2683
# 12.50      477
# 12.60     1885
# 12.75      778
# 12.80     1235
# 13.00      226
# 13.20     1379
# 13.25      381
# 13.40      772
# 13.50      113
# 13.60      412
# 13.75      162
# 13.80      270
# 14.00       20
# 14.20      223
# 14.25       59
# 14.40       77
# 14.50        9
# 14.60       35
# 14.75        9
# 14.80       19
# 15.00        1
# 15.20        2
# 15.25        1
# 15.75        2
# 15.80        2
# Name: grade_numeric_plus_minus, dtype: int64

# %% [markdown]
# Inclusion of the +/- is really important if we want to see more variability in the lower grades.

# %%
#distribution of grades by + or - or neither
plt.figure(figsize=(10, 5))
plt.hist(routes[routes['plus_minus'] == 0]['grade_numeric'].apply(np.floor), bins=range(0, 16), label='No Plus or Minus', alpha=.7)
plt.hist(routes[routes['plus_minus'] == 1]['grade_numeric'], bins=range(0,16), label='Plus', alpha=.6, color='r')
plt.hist(routes[routes['plus_minus'] == -1]['grade_numeric'], bins=range(0,16), label='Minus', alpha=.5, color='gold')
plt.xticks(ticks=range(0,16), labels=grade_labels)
plt.title("Distribution of Grades by Plus, Minus, or Neither")
plt.xlabel("Grade (YDS)")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# I am not surprised to see that plus-grades have a lower average grade distribution. '+' is often a feature seen on older routes that were established before grades above 5.10 were common. In grades above 5.10, a letter grade is much more common than a plus or minus, as it is more precise.

# %%
#distribution of +/- by year
plt.figure(figsize=(10,5))
plt.hist(routes[(routes['plus_minus'] == 0) & (routes['year_established'] > 1930)]['year_established'], label="No Plus or Minus", bins=range(1930, 2025, 1), alpha=.7)
plt.hist(routes[(routes['plus_minus'] == 1) & (routes['year_established'] > 1930)]['year_established'], label="Plus", color='r', bins=range(1930, 2025, 1), alpha=.7)
plt.hist(routes[routes['plus_minus'] == -1]['year_established'], label="Minus", color='gold', bins=range(1930, 2025, 1), alpha=.7)
plt.xticks(ticks=range(1930, 2021, 10))
plt.title("Distribution of Number of Climbs Established by Year and Plus, Minus, or Neither")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# Interestingly, there seems to be an upward trend in total number of +/- grades assigned every year. This was not what I expected, so I wanted to look at the number of +/- routes in proportion to the total number of new routes every year.

# %%
#plus/minus/neither as proportion of total climbs established
plt.figure(figsize=(10, 5))
plt.plot(range(1930, 2023), routes.groupby('year_established')['plus'].mean().loc[1930:], color='r', alpha=.7, label="Plus")
plt.plot(range(1930, 2023), routes.groupby('year_established')['minus'].mean().loc[1930:], color='gold', alpha=.7, label='Minus')
plt.xticks(ticks=range(1930, 2021, 10))
plt.title("Percent of +/- Routes Established By Year")
plt.xlabel("Year")
plt.ylabel("Percent of Total Routes Established\n(Per Each Year)", size=12)
plt.show()

# %% [markdown]
# Here I see more of the trends I was expecting, with great spikes in the use of the '+' designation earlier on, petering out a bit into the 1980s and 90s. I was not expecting, however, to see the rise in their use again starting in the early 2000s. This bimodal distribution is more clear when viewed as a proportion than it was in the larger plot above. This made me curious about the distribution of the establishment years of the 5.9+ grade specifically, as that is known to be a grade that feels much different depending on the year established.

# %%
#distribution of 5.9+ by year, twiny https://stackoverflow.com/questions/22853118/twiny-in-matplotlib-changes-the-y-axis-scale
#plt.hist(routes[~(routes['grade.YDS'] == '5.9+')]['year_established'], bins=range(1950, 2023, 2))
plt.figure(figsize=(10,5))
plt.hist(routes[routes['grade.YDS'] == '5.9+']['year_established'], bins=range(1950, 2023, 1))
plt.title("Distribution of 5.9+ Routes by Year Established")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %%
routes[(routes['grade.YDS'] == '5.9+') & (routes['year_established'].notna())]['year_established'].median()
# Out:
# 2001.5

# %% [markdown]
# A similar slightly bimodal distribution shows up here, countering the commonly-touted idea that many 5.9+ routes are older. Just as many have been established since 2001 as were established prior to that year.
#
# #### Distribution of Grades by Route Type
# Route type is an interesting, potentially useful feature. Due to the differences in technicality in the different styles of climbing, I expect to see that there will be slightly different distributions. Sport, being the most ubiquitous style of climbing, and also where the upper limits tend to be pushed, will likely have a thinner left tail to the lower grades, while I expect to see that the more technical styles of climbing such as Ice, Snow, and Mixed will tend to center more around the lower grades, perhaps with right tails to the higher grades.

# %%
#distribution of grades by climb type - 7 types
type_cols = [x for x in routes.columns if "type" in x]

fig, ax = plt.subplots(len(type_cols), 1, figsize=(10, 6.5*len(type_cols)))
for i, col in enumerate(type_cols):
    col_name = col.split(".")[1].title()
    ax[i].hist(routes[routes[col] == 1]['grade_numeric'], bins=range(0,16))
    ax[i].set_xticks(ticks=range(0,16), labels=grade_labels)
    ax[i].set_title(f"Distribution of {col_name} Grades: {routes[col].sum()} Climbs Total")
    ax[i].set_xlabel("Grade (YDS)")
    ax[i].set_ylabel("Count")
    ax[i].axvline(routes[routes[col] == 1]['grade_numeric'].mean(), color='r', label=f"Mean Grade: {'5.' + str(round(routes[routes[col] == 1]['grade_numeric'].mean()))}")
    ax[i].legend()

# %% [markdown]
# Generally, the more difficult or high-risk the climbing, the lower the average grade, and the larger of a left tail it has. Sport is the most popular category of climbing, and also where people tend to push their skills because it is (generally) less risky, and less technical than Trad, the second most popular. General wisdom is that you should aim to climb Trad routes that are 2 grades lower than what you're used to, which is what we see playing out in the averages here.
#
# I was a little surprised to see that Alpine had such a high average grade, and similar distribution to Trad and Tr. Snow, Ice, and Mixed, given their technicality, were expected to have lower average grades, although the normality of the distribution, rather than a right skew, were interesting to see.
#
# I think in the upper and lower grades these features may be helpful, but in the 5.8-5.11 range they are less likely to be.

# %% [markdown]
# ### Baseline NLP Features
# Features such as word count and character count in the Description, Location, and Protection columns may have some correlation with the target grades.

# %%
nlp_cols = ['description', 'location', 'protection']

for col in nlp_cols:
    routes[f"{col}_word_count"] = routes[col].apply(lambda x: len(x.split(" ")) if type(x) == str else np.nan)
    routes[f"{col}_char_count"] = routes[col].apply(lambda x: len(x) if type(x) == str else np.nan)

# %%
routes.corr()['grade_numeric'].sort_values(key=abs, ascending=False)
# Out:
# grade_numeric               1.000000
# grade_numeric_plus_minus    0.994647
# type.sport                  0.366216
# type.trad                  -0.315425
# type.tr                    -0.193611
# year_established            0.117264
# plus_minus                 -0.089658
# plus                       -0.074739
# location_word_count        -0.067751
# location_char_count        -0.066343
# protection_char_count      -0.059110
# protection_word_count      -0.055890
# minus                       0.055204
# metadata.mp_sector_id      -0.049923
# type.snow                  -0.048926
# type.alpine                -0.046611
# type.ice                   -0.038134
# type.mixed                 -0.024130
# description_char_count      0.013998
# metadata.mp_route_id       -0.010693
# description_word_count      0.008966
# Name: grade_numeric, dtype: float64

# %% [markdown]
# Good signs here for our route type features. Although 30% correlation is not ideal, it's good to see that some features are above 10% (positive and negative agnostic). Year established also shows a slightly higher correlation, but only at 11% (and again, is only for 1/3 of the dataset).

# %% [markdown]
# ### NLP Cleaning
